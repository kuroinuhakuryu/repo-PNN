# %% [markdown]
# ## Определение тональности текстов отзывов на сайте [YELP](https://www.yelp.com/dataset) одномерной сверточной нейросетью
#
# Учебный курс "[Программирование глубоких нейронных сетей на Python](https://openedu.ru/course/urfu/PYDNN/)".

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, MaxPooling1D, Conv1D, GlobalMaxPooling1D, Dropout
from tensorflow.keras import utils
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/dl-urfu-yelp/sample_submission.csv
# /kaggle/input/dl-urfu-yelp/train.csv
# /kaggle/input/dl-urfu-yelp/test.csv
# /kaggle/input/dl-urfu-yelp/train_label.csv

# %% [markdown]
# Загружаем данные

# %%
KAGGLE_PATH = '/kaggle/input/dl-urfu-yelp/'
x_train = pd.read_csv(KAGGLE_PATH + 'train.csv')
y_train = pd.read_csv(KAGGLE_PATH + 'train_label.csv', index_col=0)
x_test = pd.read_csv(KAGGLE_PATH + 'test.csv')
x_train.shape, y_train.shape, x_test.shape,
# Out:
# ((560000, 1), (560000, 1), (4000, 1))

# %% [markdown]
# ## Подготовка данных для обучения

# %% [markdown]
# ### Токенизация текста

# %%
# извлекаем столбец с текстом
x_train = x_train.Review
x_test = x_test.Review

# %%
# указываем длину словаря, который мы будем использовать
num_words = 10000
# указываем длину последовательности, к которой приведем все тексты
max_review_len = 450
# создаем и обучаем токенизатор на тернировочных данных
tokenizer = Tokenizer(num_words=num_words)
tokenizer.fit_on_texts(x_train)
# применяем токенизатор к тренировочным и тестовым данным
x_train = tokenizer.texts_to_sequences(x_train)
x_test = tokenizer.texts_to_sequences(x_test)
# приводим все вектора текстов к общей длине
x_train = pad_sequences(x_train, maxlen=max_review_len, padding='post')
x_test = pad_sequences(x_test, maxlen=max_review_len, padding='post')

# %% [markdown]
# ## Создание нейронной сети

# %%
model = Sequential()
model.add(Embedding(num_words, 128, input_length=max_review_len))
model.add(Conv1D(125, 9, padding='valid', activation='relu'))
model.add(Conv1D(125, 9, padding='valid', activation='relu'))
model.add(MaxPooling1D())
model.add(Conv1D(250, 9, padding='valid', activation='relu'))
model.add(Conv1D(250, 9, padding='valid', activation='relu'))
model.add(MaxPooling1D())
model.add(Conv1D(500, 9, padding='valid', activation='relu'))
model.add(Conv1D(500, 9, padding='valid', activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.9))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer="adam", 
              loss='binary_crossentropy', 
              metrics=['accuracy'])

# %%
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', 
                              factor=0.2,
                              patience=5, 
                              min_lr=0.00001,
                              verbose=1)

# %%
save_best = ModelCheckpoint(filepath="best_weights.hdf5",
                            monitor="val_accuracy",
                            save_best_only=True,
                            mode="auto",
                            verbose=1)

# %% [markdown]
# ## Обучаем нейронную сеть

# %%
history = model.fit(x_train, 
                    y_train, 
                    epochs=12,
                    batch_size=1024,
                    validation_split=0.1,
                    verbose=2,
                    callbacks=[save_best, reduce_lr],
                    )
# Out:
# Epoch 1/12
# 493/493 - 386s - loss: 0.2341 - accuracy: 0.9020 - val_loss: 0.1074 - val_accuracy: 0.9604
#
# Epoch 00001: val_accuracy improved from -inf to 0.96041, saving model to best_weights.hdf5
# Epoch 2/12
# 493/493 - 390s - loss: 0.1356 - accuracy: 0.9517 - val_loss: 0.1681 - val_accuracy: 0.9420
#
# Epoch 00002: val_accuracy did not improve from 0.96041
# Epoch 3/12
# 493/493 - 389s - loss: 0.1074 - accuracy: 0.9623 - val_loss: 0.1058 - val_accuracy: 0.9619
#
# Epoch 00003: val_accuracy improved from 0.96041 to 0.96189, saving model to best_weights.hdf5
# Epoch 4/12
# 493/493 - 389s - loss: 0.0825 - accuracy: 0.9710 - val_loss: 0.1129 - val_accuracy: 0.9636
#
# Epoch 00004: val_accuracy improved from 0.96189 to 0.96361, saving model to best_weights.hdf5
# Epoch 5/12
# 493/493 - 392s - loss: 0.0610 - accuracy: 0.9791 - val_loss: 0.1264 - val_accuracy: 0.9622
#
# Epoch 00005: val_accuracy did not improve from 0.96361
# Epoch 6/12
# 493/493 - 392s - loss: 0.0411 - accuracy: 0.9862 - val_loss: 0.1937 - val_accuracy: 0.9558
#
# Epoch 00006: val_accuracy did not improve from 0.96361
# Epoch 7/12
# 493/493 - 392s - loss: 0.0325 - accuracy: 0.9891 - val_loss: 0.2462 - val_accuracy: 0.9525
#
# Epoch 00007: val_accuracy did not improve from 0.96361
# Epoch 8/12
# 493/493 - 390s - loss: 0.0272 - accuracy: 0.9909 - val_loss: 0.2133 - val_accuracy: 0.9580
#
# Epoch 00008: val_accuracy did not improve from 0.96361
# Epoch 9/12
# 493/493 - 385s - loss: 0.0214 - accuracy: 0.9929 - val_loss: 0.2373 - val_accuracy: 0.9596
#
# Epoch 00009: val_accuracy did not improve from 0.96361
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 10/12
# 493/493 - 384s - loss: 0.0092 - accuracy: 0.9971 - val_loss: 0.3907 - val_accuracy: 0.9602
#
# Epoch 00010: val_accuracy did not improve from 0.96361
# Epoch 11/12
# 493/493 - 383s - loss: 0.0036 - accuracy: 0.9988 - val_loss: 0.5180 - val_accuracy: 0.9601
#
# Epoch 00011: val_accuracy did not improve from 0.96361
# Epoch 12/12
# 493/493 - 382s - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.5863 - val_accuracy: 0.9601
#
# Epoch 00012: val_accuracy did not improve from 0.96361

# %%
plt.plot(history.history['accuracy'], 
         label='Доля верных ответов на обучающем наборе')
plt.plot(history.history['val_accuracy'], 
         label='Доля верных ответов на проверочном наборе')
plt.xlabel('Эпоха обучения')
plt.ylabel('Доля верных ответов')
plt.legend()
plt.show()

# %% [markdown]
# ## Готовим данные для LeaderBoard

# %%
model.load_weights("best_weights.hdf5")

# %%
sample_submission = pd.read_csv(KAGGLE_PATH + 'sample_submission.csv', index_col='id')
sample_submission.label = model.predict_classes(x_test)
sample_submission.to_csv("submission.csv")
# Out:
# /opt/conda/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '
